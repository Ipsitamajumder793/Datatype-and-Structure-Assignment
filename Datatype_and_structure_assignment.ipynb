# %%
# Theory Questios #
'''  
       1. What are Data Structure & why are the important ?
           Ans:-  Data structures are ways of organizing and storing data in a computer so that they can be used efficiently.
           They define the relationship between the data and the operations that can be performed on the data. In Python, data structures are
           crucial for building efficient and scalable programs. 
                 Data structures are important for several reasons:
                 Efficiency:
                     They allow for efficient storage and retrieval of data, which is crucial for performance, especially when dealing with large
                     datasets.
                 Organization:
                     They provide a way to organize data logically, making it easier to understand and work with.
                 Problem Solving:
                     They provide a framework for solving complex problems by allowing you to choose the right data structure for a specific task.
                 Reusability:
                     They can be reused across different applications, saving time and effort.

         2. Explain the difference between mutable and immutable data types with examples.         
            Ans:- Mutable data types: 
                    These are data types whose values can be modified in place after creation. Examples include lists, dictionaries, and sets.
                    my_list = [1, 2, 3]
                    my_list.append(4)
                    print(my_list)
    
    
                    my_dict = {'a': 1, 'b': 2}
                    my_dict['c'] = 3 
                    print(my_dict) 
    
   
                    my_set = {1, 2, 3}
                    my_set.add(4) 
                    print(my_set)

                 Immutable data types: These are data types whose values cannot be changed after creation. Any operation that appears to modify
                 an immutable object actually creates a new object with the modified value. Examples include integers, floats, strings, and tuples.
                    my_tuple = (1, 2, 3)
                    my_tuple[0] = 4  # This would raise an error

          3. What are the main difference between list and tuple in Python ?
             Ans: - The main difference between tuples and lists is that tuples are immutable, meaning their contents cannot be changed after
             creation, while lists are mutable and can be modified. Additionally, tuples are more memory-efficient compared to lists.

          4. Describe how dictionary stored data in Python?
             Ans:-  Dictionaries are used to store data values in key:value pairs.
                    A dictionary is a collection which is ordered, changeable and do not allow duplicates.
                    e.g-  my_dict = {'a': 1, 'b': 2}


          5. Why might you use a set instead of list in Python ?
             Ans:-  A set in Python is an unordered collection of unique elements,
             while a list is an ordered collection that can contain duplicate elements. There are several reasons why you might choose to use
             a set instead of a list:

                    Uniqueness:

                       If you need to ensure that there are no duplicate elements in your collection, a set is the way to go.
                       Adding an element that already exists in the set has no effect.

                    Membership testing:

                       Checking if an element is present in a set is much faster than checking if it is present in a list.
                       This is because sets are implemented using hash tables, which allow for constant-time lookups.

                    Set operations:

                       Sets provide efficient methods for performing set operations such as union, intersection, and difference.

          6.  What is a string in python and how is it different from a list ?
              Ans:-  A string is a sequence of characters between single or double quotes. 
                    Strings are immutable, meaning their values cannot be changed once they are created.
                    While both lists and strings can be accessed using indexing and slicing, lists provide more flexibility as they can be
                    modified, appended, or extended, while strings cannot be altered after creation.

          7.  How do tuples ensure Data integrity in Python ?
              Ans :- Tuples in Python ensure data integrity due to their immutability. Once a tuple is created, its elements cannot be changed, added,
                     or removed.
                    This characteristic guarantees that the data stored within a tuple remains constant throughout its lifecycle, preventing accidental
                    or unauthorized modifications. 
          8. What is the Hash table and how does it related to the dictionary in  Python ?
             Ans :- A Hash Table is a data structure that uses a hash function to map keys to values, allowing for fast retrieval of data.
                    In Python, the Dictionary data type is built upon the concept of Hash Tables. 

          9. Can list contain different data types in Python ?
             Ans:-  Yes, a list in Python can contain elements of different data types. This is one of the features that makes Python lists very
                    flexible. A single list can hold integers, strings, floats, booleans, and even other lists, tuples, dictionaries, or functions.
                    e.g.-
                     my_list = [1, "hello", 3.14, True, [1, 2, 3], (4, 5), {"name": "Alice"}]
                     print(my_list)  

          10. Explain why strings are immutable in Python ?
      
             Ans:- Strings in Python are immutable because of several design and performance considerations.
                   Immutability means that once a string is created, its value cannot be changed. Any operation that appears to modify a string 
                   actually creates a new string object.
                   One key reason for string immutability is to allow strings to be used as keys in dictionaries.
                   Dictionaries require their keys to be hashable, and mutability would break the hashing mechanism.
                   If a string used as a key were to change, its hash value would change, and the dictionary would no longer be able to locate the
                   entry.
          11. What advantages do dictionaries offer over lists for certain tasks in Python?
              Ans:-
                   Dictionaries in Python offer several advantages over lists for specific tasks:
                    Efficient lookups:
                    Dictionaries use a hash table implementation, allowing for near-constant time complexity, O(1), for retrieving values based on 
                    their keys. Lists, on the other hand, require linear time complexity, O(n), for searching, as they may need to iterate through
                    each element until the target is found.
                    Key-value association:
                    Dictionaries store data in key-value pairs, making them ideal for representing relationships between data elements. This 
                    structure enables direct access to values using their corresponding keys, which is more intuitive and efficient than accessing 
                    elements by index in a list.
                    Flexibility:
                    Dictionaries can store values of any data type, and keys can be immutable types like strings, numbers, or tuples.
                    This flexibility allows for representing complex data structures and relationships.
                    Uniqueness of keys:
                    Dictionaries enforce the uniqueness of keys, ensuring that each key is associated with only one value. This property
                    is useful for maintaining data integrity and avoiding ambiguity.
                    Dynamic nature:
                    Dictionaries are mutable, allowing for the addition, modification, and deletion of key-value pairs after creation. 
                    This dynamic nature makes them suitable for tasks where data changes frequently.
                    In summary, dictionaries excel in scenarios requiring fast lookups, key-value associations, and flexible data storage, 
                    while lists are more appropriate for ordered collections and sequential processing.

         12. Describe a scenario where using a tuple would be preferable over a list .
               Ans:-
                    Tuples are immutable. Hence, they are primarily used to store data that doesn't change frequently.
                    Any operation can store data in a tuple when you don't want it to change.
                    Tuples are great to use if you want the data in your collection to be read-only, never to change,
                    and always remain the same and constant.
            
         13. How do sets handle duplicate values in Python?
               Ans:- 
                    Sets in Python are designed to store only unique elements.
                    When attempting to add a duplicate value to a set, Python automatically discards the duplicate, 
                    ensuring that the set retains only distinct values. This behavior makes sets useful for tasks such as removing duplicates
                    from a list or checking for the presence of unique items.

                    E.g. -
                     my_set = {1, 2, 2, 3, 4, 4, 5}
                    print(my_set)
                    # Expected output: {1, 2, 3, 4, 5}

         14. How does the "in" keyword work differently for lists and dictionaries in Python ?
               Ans :- 
                     For lists, the in keyword performs a sequential search.
                        E.g. --- 
                        List :-
                        my_list = [10, 20, 30, 40, 50]
                        print(30 in my_list)  
                        
                        print(60 in my_list)
                        
                        Dictionary :-
                        
                    For dictionaries, the in keyword checks for the existence of a key. Dictionaries are implemented as hash tables,
                    which allow for near-constant time lookups on average. 
                        
                        E.g.-
                        my_dict = {"a": 1, "b": 2, "c": 3}
                        print("b" in my_dict)  
                        print("d" in my_dict)
                        
        15. Can you modify the elements of a Tuple? Explain why or why not.
             Ans:-
                   Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.

                    But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.
                    
                    E.g.-
                    x = ("apple", "banana", "cherry")
                    y = list(x)
                    y[1] = "kiwi"
                    x = tuple(y)
                    
                    print(x)


          
          
        16. What is a nested dictionary and give an example of its use case?
             Ans:-
                   A nested dictionary in Python is a dictionary where one or more of its values are themselves dictionaries. 
                   This allows you to create a hierarchical structure for organizing data, similar to a tree or database schema.

                   Example Use Case:
                   Imagine you need to store employee information for a company, including their department and other details.
                   You could use a nested dictionary to organize this data effectively: 

                    E.g. -
                    company_data = {
                        "Engineering": {
                            "employees": {
                                "123": {"name": "Alice", "role": "Software Engineer"},
                                "456": {"name": "Bob", "role": "Project Manager"}
                            },
                            "location": "Main Building"
                        },
                        "Marketing": {
                            "employees": {
                                "789": {"name": "Charlie", "role": "Marketing Manager"}
                            },
                            "location": "West Wing"
                        }
                    }
                    
                    print(company_data["Engineering"]["employees"]["123"]["name"])  
                    # Output: Alice
                    print(company_data["Marketing"]["location"]) 
                    # Output: West Wing     



           17. Describe the time complexity of accessing elements in a dictionary. 
               Ans :-
                    Python  dictionaries provide a fast and efficient way to store and retrieve data using key value pair so understanding the 
                    time complexities of dictionary operations is very important for optimizing performance in our programs.

                    Adding a new key-value pair or updating an existing key is also O(1) in average cases as the dictionary directly places 
                    the value in the hash table.
                    
                    Deleting an Element (O(1))
                    Removing an element by its key also has an average time complexity of O(1) using the same hash table mechanism.
                    
                    Iterating Over a Dictionary (O(n))
                    Iterating over keys, values, or items in a dictionary has a time complexity of O(n) where n is the number of elements.
                    
                    Using the keys() or values() method to retrieve all keys or values takes O(n) time since it involves traversing the dictionary.
                    
                    Copying a Dictionary (O(n))
                    Copying a dictionary creates a shallow copy and its time complexity is O(n) as each key-value pair is duplicated.
                    
                    Clearing a Dictionary (O(1))
                    The clear() method removes all elements from the dictionary with a time complexity of O(1).



            18. In what situations are least preferred over dictionaries?
              Ans:-
                    Dictionaries are used for fast lookups, key-value associations, and complex data mappings,
                    while lists are ideal for ordered collections, sequential processing, and simple data storage.


            19.  Why are dictionary is considered unordered and how does that affect data retrieval? 
            
                Ans :- 
                A dictionary is termed an unordered collection of objects because dictionaries do not maintain any inherent order of the items based on when they were added.
                
                 How Unorderedness Affects Data Retrieval:
                
                Key-Based Access: Data retrieval in dictionaries is always done using the key, not an index.
                No Sequential Access: You can't iterate through a dictionary in a predictable sequence or access elements by their position.
                Order is Not Guaranteed: The order in which key-value pairs are added, or the order they are returned during iteration, is not guaranteed
                

            20. Explain the difference between a list and the dictionary in terms of data retrieval.
                
                Ans:-
                       A list is an ordered collection of items, whereas a dictionary is an unordered data collection in a key: value pair.
                Elements from the list can be accessed using the index, while the elements of the dictionary can be accessed using keys.
                The list allows duplicate items, while the dictionary does not allow any duplicate keys.
                A list can store any data type. In contrast, keys in the dictionary can be of any immutable data type, and values can be of any data type.
                Lists perform faster for ordered operations like sorting, while dictionaries perform faster for lookup operations.
                
                E.g.-
                List:-
                To access a list element by index, square bracket notation is used: list[index]
                
                berries = ["blueberry", "cranberry", "raspberry"]
                
                berries[0]   # "blueberry"
                berries[2]   # "raspberry"
                
                Dictionary:-
                
                d = { "name": "Alice", 1: "Python", (1, 2): [1,2,4] }
                
                # Access using key
                print(d["name"])
                
                # Access using get()
                print(d.get("name"))

   '''

# PRACTICAL QUESTIONS :: #

# 1. Write a code to create a string with your name and print it .#
name="Ipsita Majumder"
print("My name is =",name)


# 2. Write a code to find the length of a string hello world.  #
string = "hello world"
length = len(string)
print("The length of the string is:", length)


# 3. Write a code to slice the first three characters of the string "Python programming". #
s = "Python programming"
print(s[0:3])


# 4. Write a code to convert the string "hello" to uppercase . #
string = "hello"
uppercase_string = string.upper()
print(uppercase_string)


# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple'. #
text ='I like apple'
print("Original ",text)
text = text.replace('apple', 'orange')
print("Replaced ",text)



# 6. Write a code to create a list with numbers 1 to 5 and print it. #
a = [1,2,3,4,5]
print(a)


# 7. Write a code to append the number 10 to the list [1,2,3,4] . #
my_list = [1, 2, 3, 4]
print("Before append = ",my_list)
my_list.append(10)
print("After append = ",my_list)


# 8. Write a code to remove the number 3 from the list [1,2,3,4,5] .  #
my_list = [1, 2, 3, 4, 5]
print("Before remove",my_list)
my_list.remove(3)
print("After remove",my_list)


# 9. Write a code to access the second element in the list ['a','b','c','d'] .   #
my_list = ['a', 'b', 'c', 'd']
print("Actual list = ",my_list)
second_element = my_list[1]
print("The second element is = ",second_element)


# 10. Write a code to reverse the list [10,20,30,40,50].  #
my_list = [10, 20, 30, 40, 50]
print("Original list = ",my_list)
my_list.reverse()
print("Reversed list = ",my_list)


# 11. Write a code to create a tuple with the elements 100,200,300 and print it  #
my_tuple = (100, 200, 300)
print("Tuple elements are = ",my_tuple)


# 12. Write a code to access the second to last element of the tuple ("red","green","blue","yellow"). #
colors = ["red", "green","blue","yellow"]
x=colors[len(colors)-2]
print("Second last element of the Tuple is = ",x)


# 13. Write a code to find the minimum number in the tuple (10,20,5,15) #
my_tuple = (10, 20, 5, 15)
print("The tuple",my_tuple)
min_number = min(my_tuple)
print("Minimum number = ",min_number)


# 14. Write a code to find the index of the element 'cat' in the tuple ('dog','cat', 'rabbit') #
my_tuple = ('dog', 'cat', 'rabbit')
print("The Tuple= ",my_tuple)
index_of_cat = my_tuple.index('cat')
print("cat is present at ",index_of_cat," location")


# 15. Write a code to create a tuple containing three different fruits and check it "kiwi" is in it? #
fruits = ("apple", "banana", "cherry")
print("First Tuple elements are :: ",fruits)
if "kiwi" in fruits:
  print("kiwi is present in the first tuple")
else:
  print("kiwi is not present in the first tuple")
fruits1 = ("apple", "kiwi", "cherry")
print("Second Tuple elements are :: ",fruits1)
if "kiwi" in fruits1:
  print("kiwi is present in the second tuple")
else:
  print("kiwi is not present in the second tuple")    


# 16. Write a code to create a set with the elements 'a','b','c' and print it #
my_set = {'a', 'b', 'c'}
print("The Set elements are = ",my_set)


# 17. Write a code to clear all elements from the set {1,2,3,4,5} #
my_set = {1, 2, 3, 4, 5}
print("Set elements are ",my_set)
my_set.clear()
print("After clear set elements are ",my_set)


# 18. Write a code to remove the element 4 from the set {1,2,3,4} #
my_set = {1, 2, 3, 4}
print("Before discarding ",my_set)
my_set.discard(4)
print("After discarding ",my_set)


# 19. Write a code to find the union of two sets  {1,2,3} and {3,4,5} #
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print ("First set",set1)
print ("Second set",set2)
union_set = set1.union(set2)
print("After union = ",union_set)


# 20. Write a code to find the intersection of two sets  {1,2,3} and {2,3,4} #
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print("First set = ",set1)
print("Second set = ",set2)
intersection_result = set1.intersection(set2)
print("After intersection = ",intersection_result)


# 21. Write a code to create a dictionary with keys "name", "age" and "city" and print it  #
my_dict = {
    "name": "Ipsita Majumder",
    "age": 45,
    "city": "Kolkata"
}

print(my_dict)


# 22. Write a code to add a new key-value pair "country":"USA" to the dictionary {'name':'John','age': 25} #
my_dict = {'name': 'John', 'age': 25}
print(my_dict)
my_dict['country'] = 'USA'
print(my_dict)


# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice','age':30}  #
my_dict = {'name': 'Alice', 'age': 30}
name_value = my_dict['name']
print(name_value)



# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob','age':22,'city': 'New York'}  #
person = {
    'name': 'Bob',
    'age': 22,
    'city': 'New York'
}
print("Before ",person)
del person['age']
print("After ",person)



# 25. Write a code to check if the key "city" exist in the dictionary {'name': 'Alice','city':'Paris'}   #
student = {'name':'Alice','city':'Paris'}

if 'city' in student:
    print("Key exists.")
else:
    print("Key does not exist.")



# 26. Write a code to create a list,a tuple and the dictionary and print them all   #
# Create a list
my_list = [1, 2, 3, "apple", "banana"]

# Create a tuple
my_tuple = (4, 5, 6, "orange", "grape")

# Create a dictionary
my_dictionary = {"name": "John", "age": 30, "city": "New York"}

# Print the list
print("List:", my_list)

# Print the tuple
print("Tuple:", my_tuple)

# Print the dictionary
print("Dictionary:", my_dictionary)




# 27. Write a code to create a list of five random numbers between 1 and 100, sort it in ascending order, and print the result.( replaced)  #
import random

# Create a list of five random numbers between 1 and 100
random_numbers = [random.randint(1, 100) for _ in range(5)]

# Sort the list in ascending order
random_numbers.sort()

# Print the sorted list
print(random_numbers)



# 28. Write a code to create a list with strings and print the element at the third index   #
thislist = ["apple", "banana", "cherry","grapes","nuts"]
print("Whole list",thislist)
print("Element in third index",thislist[2])



#  29. Write a code to combine two dictionary into one and print the result #
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 4, 'd': 5}
combined_dict = dict1.copy()
combined_dict.update(dict2)
print(combined_dict)



# 30. Write a code to convert a least of strings into a set  #
my_list = ["apple", "banana", "cherry", "apple"]
string_set = my_list
print(string_set)
print(type(string_set))
string_set = set(my_list)
print(string_set)
print(type(string_set))
# Out:
# My name is = Ipsita Majumder
# The length of the string is: 11
# Pyt
# HELLO
# Original  I like apple
# Replaced  I like orange
# [1, 2, 3, 4, 5]
# Before append =  [1, 2, 3, 4]
# After append =  [1, 2, 3, 4, 10]
# Before remove [1, 2, 3, 4, 5]
# After remove [1, 2, 4, 5]
# Actual list =  ['a', 'b', 'c', 'd']
# The second element is =  b
# Original list =  [10, 20, 30, 40, 50]
# Reversed list =  [50, 40, 30, 20, 10]
# Tuple elements are =  (100, 200, 300)
# Second last element of the Tuple is =  blue
# The tuple (10, 20, 5, 15)
# Minimum number =  5
# The Tuple=  ('dog', 'cat', 'rabbit')
# cat is present at  1  location
# First Tuple elements are ::  ('apple', 'banana', 'cherry')
# kiwi is not present in the first tuple
# Second Tuple elements are ::  ('apple', 'kiwi', 'cherry')
# kiwi is present in the second tuple
# The Set elements are =  {'a', 'b', 'c'}
# Set elements are  {1, 2, 3, 4, 5}
# After clear set elements are  set()
# Before discarding  {1, 2, 3, 4}
# ...
